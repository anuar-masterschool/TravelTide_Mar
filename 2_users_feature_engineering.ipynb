# %% [markdown]
# # Users Feature engineering
#
# We will create the columns that are intersing for our users

# %%
import pandas as pd

# %%
sessions = pd.read_csv('data/sessions.csv')
users = pd.read_csv('data/users.csv')
flights = pd.read_csv('data/flights.csv')
hotels = pd.read_csv('data/hotels.csv')

# %% [markdown]
# id from trips that were cancelled

# %%
cancelled_trip_ids = sessions[sessions['cancellation']]['trip_id']

# %% [markdown]
# ## Columns directly from users table

# %%
users.columns
# Out:
# Index(['user_id', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date'],
#       dtype='str')

# %% [markdown]
# directly took columns from user table

# %%
user_features = users[['user_id', 'gender', 'married', 'has_children', 'home_country']].copy()

# %% [markdown]
# ## Tenure

# %%
user_features['tenure'] = (pd.Timestamp.today() - pd.to_datetime(users['sign_up_date'])).dt.days # feature column

# %% [markdown]
# Idea: From this column create group of new customers.

# %% [markdown]
# ## Age

# %%
users.columns
# Out:
# Index(['user_id', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date'],
#       dtype='str')

# %%
user_features['age']  = (pd.Timestamp.today() - pd.to_datetime(users['birthdate'])).dt.days//365

# %%
user_features
# Out:
#       user_id gender  married  has_children home_country  tenure  age
# 0       94883      F     True         False          usa    1505   54
# 1      101486      F     True          True          usa    1495   53
# 2      101961      F     True         False          usa    1495   45
# 3      106907      F     True          True          usa    1488   47
# 4      118043      F    False          True          usa    1474   53
# ...       ...    ...      ...           ...          ...     ...  ...
# 5777   780167      F     True          True          usa    1063   51
# 5778   785186      F     True          True          usa    1061   46
# 5779   792549      F    False         False          usa    1058   48
# 5780   811077      F     True          True          usa    1052   47
# 5781   844489      M    False          True          usa    1040   25
#
# [5782 rows x 7 columns]

# %% [markdown]
# ## Overcarrier

# %%
flights
# Out:
#                                        trip_id origin_airport   destination  \
# 0      363535-ae2567b185da4e3994607ce71f98a96b            CLT       phoenix
# 1      549482-f5e7931dd7b6460b90b89ea0aaabfc78            YVR     san diego
# 2      585745-7f13ca3cb64441e08ba34a3020e7ff7b            LBB      new york
# 3      596153-eb736cf7fe6f4aaf8c1638e399111ced            YKZ       calgary
# 4      636526-80cabddfe58c406d9ba90c77f85c66ff            LGA   los angeles
# ...                                        ...            ...           ...
# 13188  544449-e96a99d225be4ca2862bfa16d02f94d9            LGA       chicago
# 13189  566735-978b549aa0804742883e1a10e57d6790            BOS  indianapolis
# 13190  580611-b8fc699133a8430a935067cd85f68549            JFK      montreal
# 13191  588386-233db0f627cf4aaaaeaa9a632daa5ec4            CLE  philadelphia
# 13192  623941-eb2a6cb1fdde4a3aabb65da862f26524            YYZ       memphis
#
#       destination_airport  seats  return_flight_booked  \
# 0                     PHX      1                 False
# 1                     SAN      1                  True
# 2                     JFK      1                  True
# 3                     YYC      1                  True
# 4                     LAX      1                  True
# ...                   ...    ...                   ...
# 13188                 MDW      2                  True
# 13189                 IND      1                  True
# 13190                 YUL      1                  True
# 13191                 PHL      1                  True
# 13192                 MEM      1                  True
#
#                    departure_time                 return_time  checked_bags  \
# 0      2023-01-13 15:00:00.000000                         NaN             0
# 1      2023-07-25 11:00:00.000000  2023-07-31 11:00:00.000000             1
# 2      2023-07-24 07:00:00.000000  2023-07-29 07:00:00.000000             0
# 3      2023-07-25 15:00:00.000000  2023-07-27 15:00:00.000000             1
# 4      2023-07-23 13:00:00.000000  2023-07-26 13:00:00.000000             1
# ...                           ...                         ...           ...
# 13188  2023-03-30 08:00:00.000000  2023-04-01 08:00:00.000000             0
# 13189  2023-04-02 09:00:00.000000  2023-04-06 09:00:00.000000             1
# 13190  2023-03-31 11:00:00.000000  2023-04-05 11:00:00.000000             0
# 13191  2023-04-04 08:00:00.000000  2023-04-06 08:00:00.000000             2
# 13192  2023-04-01 13:00:00.000000  2023-04-05 13:00:00.000000             0
#
#             trip_airline  destination_airport_lat  destination_airport_lon  \
# 0        Alaska Airlines                   33.535                 -112.383
# 1      American Airlines                   32.699                 -117.215
# 2          Allegiant Air                   40.640                  -73.779
# 3                WestJet                   51.114                 -114.020
# 4        Air New Zealand                   33.942                 -118.408
# ...                  ...                      ...                      ...
# 13188    AirTran Airways                   41.786                  -87.752
# 13189      Allegiant Air                   39.717                  -86.294
# 13190    Royal Jordanian                   45.517                  -73.417
# 13191  American Airlines                   39.872                  -75.241
# 13192    Delta Air Lines                   35.042                  -89.977
#
#        base_fare_usd
# 0             251.87
# 1             369.26
# 2             407.51
# 3             449.58
# 4             691.85
# ...              ...
# 13188         389.69
# 13189         175.15
# 13190          97.40
# 13191         106.00
# 13192         216.55
#
# [13193 rows x 13 columns]

# %%
flights_w_users = pd.merge(flights, sessions[['trip_id','user_id']], on='trip_id', how='left')

# %% [markdown]
# filter out valid trips and calculate average bags per seat

# %%
seats_avg = flights_w_users[~flights_w_users['trip_id'].isin(cancelled_trip_ids)].groupby('user_id')['seats'].mean()
seats_avg.name = "seats_avg"  # feature column

# %%
checked_bags_avg = flights_w_users[~flights_w_users['trip_id'].isin(cancelled_trip_ids)].groupby('user_id')['checked_bags'].mean()
checked_bags_avg.name = "checked_bags_avg"  # feature column

# %%
bags_per_seat = checked_bags_avg/seats_avg

# %%
overcarrier = bags_per_seat > 2  # feature column

overcarrier.name = "overcarrier"

# %% [markdown]
# ## Frequent travelers

# %%
total_trips  = sessions.groupby('user_id')['trip_id'].nunique() # feature column
total_trips.name = 'total_trips'

# %%
number_of_cancellations = sessions.groupby('user_id')['cancellation'].sum()

# %%
cancellation_rate  = number_of_cancellations/total_trips  # feature column
cancellation_rate.name = 'cancellation_rate'

# %% [markdown]
# ## Frequent destination

# %%
unique_flight_destination = flights_w_users.groupby('user_id')['destination'].nunique()
unique_flight_destination.name = 'unique_flight_destination' # feature column

# %%
taken_flights = total_trips - number_of_cancellations
taken_flights.name = 'taken_flights' # feature column

# %%
frequent_destinations = unique_flight_destination/taken_flights  # feature column
frequent_destinations.name = 'frequent_destinations'

# %% [markdown]
# ## Booking rate

# %%
total_sessions = sessions[~sessions['trip_id'].isin(cancelled_trip_ids)].groupby("user_id")['session_id'].count()
total_sessions.name = 'total_sessions'

# %%
nan_sessions = sessions[~sessions['trip_id'].isin(cancelled_trip_ids)].groupby('user_id')['trip_id'].apply(lambda x: x.isna().sum())

# %%
sessions_booking_rate = 1 - nan_sessions/total_sessions # feature column
sessions_booking_rate.name = 'sessions_booking_rate'

# %% [markdown]
# ## Percentage discounted trip

# %%
sessions
# Out:
#                                     session_id  user_id  \
# 0      519853-4c326bf41c934dbc8be18e225304e145   519853
# 1      519961-d51f73bd907c4d1b870482986df44934   519961
# 2      520819-9370019847834216ae16820953e4003d   520819
# 3      521768-a256b0bd9f7a4b79a1ef41dc75cb4cde   521768
# 4      522438-517e5c924fc14b44a97d2729b3712ae7   522438
# ...                                        ...      ...
# 47431  516579-c23ab895874c4e7da3d0ce50a693d750   516579
# 47432  518127-66b3a35543284123bfb8e615927c017d   518127
# 47433  518907-c80deed1d66c42cfa469693143c03449   518907
# 47434  519137-ffd5eb50b1894137810d6a0a10c2f35f   519137
# 47435  519357-f15efeca59d7452fa29c0d7c01ea2902   519357
#
#                                        trip_id               session_start  \
# 0                                          NaN  2023-02-23 21:17:00.000000
# 1                                          NaN  2023-02-23 10:33:00.000000
# 2                                          NaN  2023-02-23 18:55:00.000000
# 3                                          NaN  2023-02-23 21:31:00.000000
# 4      522438-818ce6433b8849e0a5ec093b4c3ac782  2023-02-23 10:04:00.000000
# ...                                        ...                         ...
# 47431                                      NaN  2023-02-23 20:00:00.000000
# 47432                                      NaN  2023-02-23 12:31:00.000000
# 47433                                      NaN  2023-02-23 09:54:00.000000
# 47434  519137-f9aa897856104fa39d7970dd058a1fea  2023-02-23 15:18:00.000000
# 47435  519357-aae7de02e83747188bf44b5cb5c6238a  2023-02-23 16:43:00.000000
#
#                       session_end  flight_discount  hotel_discount  \
# 0      2023-02-23 21:18:00.000000            False            True
# 1      2023-02-23 10:37:26.000000            False           False
# 2      2023-02-23 18:56:22.000000             True           False
# 3      2023-02-23 21:31:37.000000            False           False
# 4      2023-02-23 10:06:19.000000            False            True
# ...                           ...              ...             ...
# 47431  2023-02-23 20:01:15.000000            False           False
# 47432  2023-02-23 12:31:31.000000             True            True
# 47433  2023-02-23 09:54:25.000000            False           False
# 47434  2023-02-23 15:20:12.000000            False            True
# 47435  2023-02-23 16:44:47.000000            False           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  \
# 0                         NaN                   0.10          False
# 1                         NaN                    NaN          False
# 2                         0.1                    NaN          False
# 3                         NaN                    NaN          False
# 4                         NaN                   0.15           True
# ...                       ...                    ...            ...
# 47431                     NaN                    NaN          False
# 47432                     0.1                   0.05          False
# 47433                     NaN                    NaN          False
# 47434                     NaN                   0.05           True
# 47435                     NaN                    NaN           True
#
#        hotel_booked  page_clicks  cancellation
# 0             False            8         False
# 1             False           36         False
# 2             False           11         False
# 3             False            5         False
# 4              True           19         False
# ...             ...          ...           ...
# 47431         False           10         False
# 47432         False            4         False
# 47433         False            3         False
# 47434          True           18         False
# 47435         False           14         False
#
# [47436 rows x 13 columns]

# %%
valid_bookings = sessions[(~sessions['trip_id'].isin(cancelled_trip_ids)) & (~sessions['trip_id'].isna())].copy()

# %%
valid_bookings['discount']  = valid_bookings["flight_discount"] | valid_bookings["hotel_discount"]

# %%
discount_booking_rate = valid_bookings.groupby("user_id")['discount'].mean() # feature column
discount_booking_rate.name = 'discount_booking_rate'

# %% [markdown]
# # Create user features table by joining all the features together

# %%
user_features
# Out:
#       user_id gender  married  has_children home_country  tenure  age
# 0       94883      F     True         False          usa    1505   54
# 1      101486      F     True          True          usa    1495   53
# 2      101961      F     True         False          usa    1495   45
# 3      106907      F     True          True          usa    1488   47
# 4      118043      F    False          True          usa    1474   53
# ...       ...    ...      ...           ...          ...     ...  ...
# 5777   780167      F     True          True          usa    1063   51
# 5778   785186      F     True          True          usa    1061   46
# 5779   792549      F    False         False          usa    1058   48
# 5780   811077      F     True          True          usa    1052   47
# 5781   844489      M    False          True          usa    1040   25
#
# [5782 rows x 7 columns]

# %% [markdown]
# Example of merge

# %%
user_features.merge(discount_booking_rate, on='user_id', how='left')
# Out:
#       user_id gender  married  has_children home_country  tenure  age  \
# 0       94883      F     True         False          usa    1505   54
# 1      101486      F     True          True          usa    1495   53
# 2      101961      F     True         False          usa    1495   45
# 3      106907      F     True          True          usa    1488   47
# 4      118043      F    False          True          usa    1474   53
# ...       ...    ...      ...           ...          ...     ...  ...
# 5777   780167      F     True          True          usa    1063   51
# 5778   785186      F     True          True          usa    1061   46
# 5779   792549      F    False         False          usa    1058   48
# 5780   811077      F     True          True          usa    1052   47
# 5781   844489      M    False          True          usa    1040   25
#
#       discount_booking_rate
# 0                       0.0
# 1                       0.0
# 2                       0.2
# 3                       NaN
# 4                       0.6
# ...                     ...
# 5777                    0.5
# 5778                    0.0
# 5779                    0.0
# 5780                    0.0
# 5781                    NaN
#
# [5782 rows x 8 columns]

# %% [markdown]
# If there is a "No name" error you can solve it with the following line

# %%
sessions_booking_rate.name = 'sessions_booking_rate'

# %%
new_users = user_features.merge(sessions_booking_rate, on='user_id', how='left')

# %% [markdown]
# # Merge all Feature columns together

# %%
seats_avg
# Out:
# user_id
# 94883     1.500000
# 101486    1.000000
# 101961    1.000000
# 118043    2.000000
# 125845    1.333333
#             ...
# 785186    1.000000
# 792549    1.000000
# 796032    1.000000
# 801660    1.000000
# 811077    1.000000
# Name: seats_avg, Length: 4855, dtype: float64

# %%
user_features
# Out:
#       user_id gender  married  has_children home_country  tenure  age
# 0       94883      F     True         False          usa    1505   54
# 1      101486      F     True          True          usa    1495   53
# 2      101961      F     True         False          usa    1495   45
# 3      106907      F     True          True          usa    1488   47
# 4      118043      F    False          True          usa    1474   53
# ...       ...    ...      ...           ...          ...     ...  ...
# 5777   780167      F     True          True          usa    1063   51
# 5778   785186      F     True          True          usa    1061   46
# 5779   792549      F    False         False          usa    1058   48
# 5780   811077      F     True          True          usa    1052   47
# 5781   844489      M    False          True          usa    1040   25
#
# [5782 rows x 7 columns]

# %%
user_features_new = (user_features.merge(seats_avg, on='user_id', how='left')
 .merge(checked_bags_avg, on='user_id', how='left')
 .merge(overcarrier, on='user_id', how='left')
 .merge(total_trips, on='user_id', how='left')
 .merge(cancellation_rate, on='user_id', how='left')
 .merge(unique_flight_destination, on='user_id', how='left')
 .merge(taken_flights, on='user_id', how='left')
 .merge(frequent_destinations, on='user_id', how='left')
 .merge(sessions_booking_rate, on='user_id', how='left')
 .merge(discount_booking_rate, on='user_id', how='left'))

# %%
user_features_new
# Out:
#       user_id gender  married  has_children home_country  tenure  age  \
# 0       94883      F     True         False          usa    1505   54
# 1      101486      F     True          True          usa    1495   53
# 2      101961      F     True         False          usa    1495   45
# 3      106907      F     True          True          usa    1488   47
# 4      118043      F    False          True          usa    1474   53
# ...       ...    ...      ...           ...          ...     ...  ...
# 5777   780167      F     True          True          usa    1063   51
# 5778   785186      F     True          True          usa    1061   46
# 5779   792549      F    False         False          usa    1058   48
# 5780   811077      F     True          True          usa    1052   47
# 5781   844489      M    False          True          usa    1040   25
#
#       seats_avg  checked_bags_avg overcarrier  total_trips  cancellation_rate  \
# 0           1.5               0.5       False            2                0.0
# 1           1.0               0.0       False            2                0.0
# 2           1.0               0.4       False            5                0.0
# 3           NaN               NaN         NaN            1                1.0
# 4           2.0               1.0       False            5                0.0
# ...         ...               ...         ...          ...                ...
# 5777        1.5               0.0       False            2                0.0
# 5778        1.0               0.0       False            2                0.0
# 5779        1.0               0.5       False            4                0.0
# 5780        1.0               0.0       False            1                0.0
# 5781        NaN               NaN         NaN            0                NaN
#
#       unique_flight_destination  taken_flights  frequent_destinations  \
# 0                           2.0              2                    1.0
# 1                           1.0              2                    0.5
# 2                           5.0              5                    1.0
# 3                           1.0              0                    inf
# 4                           3.0              5                    0.6
# ...                         ...            ...                    ...
# 5777                        2.0              2                    1.0
# 5778                        2.0              2                    1.0
# 5779                        4.0              4                    1.0
# 5780                        1.0              1                    1.0
# 5781                        NaN              0                    NaN
#
#       sessions_booking_rate  discount_booking_rate
# 0                     0.250                    0.0
# 1                     0.250                    0.0
# 2                     0.625                    0.2
# 3                     0.000                    NaN
# 4                     0.625                    0.6
# ...                     ...                    ...
# 5777                  0.250                    0.5
# 5778                  0.250                    0.0
# 5779                  0.500                    0.0
# 5780                  0.125                    0.0
# 5781                  0.000                    NaN
#
# [5782 rows x 17 columns]

# %%
user_features_new.to_csv("data/user_features.csv", index = False)

# %%
df = pd.read_csv("data/user_features.csv")
df
# Out:
#       user_id gender  married  has_children  tenure  age  seats_avg  \
# 0       94883      F     True         False    1505   54        1.5
# 1      101486      F     True          True    1495   53        1.0
# 2      101961      F     True         False    1495   45        1.0
# 3      106907      F     True          True    1488   47        NaN
# 4      118043      F    False          True    1474   53        2.0
# ...       ...    ...      ...           ...     ...  ...        ...
# 5777   780167      F     True          True    1063   51        1.5
# 5778   785186      F     True          True    1061   46        1.0
# 5779   792549      F    False         False    1058   48        1.0
# 5780   811077      F     True          True    1052   47        1.0
# 5781   844489      M    False          True    1040   25        NaN
#
#       checked_bags_avg overcarrier  total_trips  cancellation_rate  \
# 0                  0.5       False            2                0.0
# 1                  0.0       False            2                0.0
# 2                  0.4       False            5                0.0
# 3                  NaN         NaN            1                1.0
# 4                  1.0       False            5                0.0
# ...                ...         ...          ...                ...
# 5777               0.0       False            2                0.0
# 5778               0.0       False            2                0.0
# 5779               0.5       False            4                0.0
# 5780               0.0       False            1                0.0
# 5781               NaN         NaN            0                NaN
#
#       unique_flight_destination  taken_flights  frequent_destinations  \
# 0                           2.0              2                    1.0
# 1                           1.0              2                    0.5
# 2                           5.0              5                    1.0
# 3                           1.0              0                    inf
# 4                           3.0              5                    0.6
# ...                         ...            ...                    ...
# 5777                        2.0              2                    1.0
# 5778                        2.0              2                    1.0
# 5779                        4.0              4                    1.0
# 5780                        1.0              1                    1.0
# 5781                        NaN              0                    NaN
#
#       sessions_booking_rate  discount_booking_rate
# 0                     0.250                    0.0
# 1                     0.250                    0.0
# 2                     0.625                    0.2
# 3                     0.000                    NaN
# 4                     0.625                    0.6
# ...                     ...                    ...
# 5777                  0.250                    0.5
# 5778                  0.250                    0.0
# 5779                  0.500                    0.0
# 5780                  0.125                    0.0
# 5781                  0.000                    NaN
#
# [5782 rows x 16 columns]
